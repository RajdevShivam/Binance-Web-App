# %%
import csv, datetime
import pandas as pd
from binance.client import Client
from binance.enums import *
from config import BinanceConfig

# %%
client = Client(BinanceConfig['Key'], BinanceConfig['Secret'])

# %%
prices = client.get_all_tickers()
for price in prices:
    print(price)
# Out:
# {'symbol': 'ETHBTC', 'price': '0.06949700'}
# {'symbol': 'LTCBTC', 'price': '0.00378700'}
# {'symbol': 'BNBBTC', 'price': '0.00853800'}
# {'symbol': 'NEOBTC', 'price': '0.00111600'}
# {'symbol': 'QTUMETH', 'price': '0.00381400'}
# {'symbol': 'EOSETH', 'price': '0.00152600'}
# {'symbol': 'SNTETH', 'price': '0.00002969'}
# {'symbol': 'BNTETH', 'price': '0.00128700'}
# {'symbol': 'BCCBTC', 'price': '0.07908100'}
# {'symbol': 'GASBTC', 'price': '0.00020370'}
# {'symbol': 'BNBETH', 'price': '0.12285000'}
# {'symbol': 'BTCUSDT', 'price': '46429.29000000'}
# {'symbol': 'ETHUSDT', 'price': '3226.83000000'}
# {'symbol': 'HSRBTC', 'price': '0.00041400'}
# {'symbol': 'OAXETH', 'price': '0.00017780'}
# {'symbol': 'DNTETH', 'price': '0.00002801'}
# {'symbol': 'MCOETH', 'price': '0.00577200'}
# {'symbol': 'ICNETH', 'price': '0.00166300'}
# {'symbol': 'MCOBTC', 'price': '0.00021140'}
# {'symbol': 'WTCBTC', 'price': '0.00001844'}
# {'symbol': 'WTCETH', 'price': '0.00023700'}
# ...

# %%
candels = client.get_klines(symbol='BTCUSDT', interval = Client.KLINE_INTERVAL_5MINUTE)
for c in candels:
    print(c)
    
print(len(candels))
# Out:
# [1628715900000, '46101.58000000', '46262.83000000', '45988.98000000', '46152.52000000', '590.46836100', 1628716199999, '27212991.35808436', 17116, '227.71625800', '10500773.92675074', '0']
# [1628716200000, '46151.00000000', '46209.00000000', '46039.00000000', '46100.48000000', '228.05514100', 1628716499999, '10512475.44325714', 6374, '91.09240600', '4199066.16225561', '0']
# [1628716500000, '46100.48000000', '46100.49000000', '45900.12000000', '45930.40000000', '374.07670100', 1628716799999, '17194153.46902466', 12194, '184.89119600', '8498668.12179347', '0']
# [1628716800000, '45930.40000000', '46039.02000000', '45911.01000000', '46011.57000000', '154.75933100', 1628717099999, '7118790.79955356', 5823, '71.38452900', '3283614.81344774', '0']
# [1628717100000, '46011.58000000', '46185.96000000', '45992.26000000', '46148.93000000', '181.92175300', 1628717399999, '8387409.95967409', 6222, '95.73776500', '4414210.67846438', '0']
# ...

# %%
candlesticks = client.get_historical_klines("ETHUSDT", Client.KLINE_INTERVAL_5MINUTE, "30 July, 2015", "14 Aug, 2021")
    
df = pd.DataFrame(candlesticks)

df.head()
# Out:
#               0             1             2             3             4   \
# 0  1502942400000  301.13000000  301.13000000  300.00000000  301.13000000
# 1  1502942700000  300.00000000  301.13000000  298.00000000  298.00000000
# 2  1502943000000  298.00000000  298.00000000  298.00000000  298.00000000
# 3  1502943300000  298.00000000  299.05000000  298.00000000  299.05000000
# 4  1502943600000  299.05000000  300.10000000  299.05000000  300.10000000
#
#             5              6              7   8           9              10  \
# 0   3.82951000  1502942699999  1152.71344160  12  3.51562000  1058.54644160
# 1   1.97216000  1502942999999   592.05266250  10  1.96830000   590.90238250
# 2   0.00000000  1502943299999     0.00000000   0  0.00000000     0.00000000
# 3  12.88486000  1502943599999  3840.08473900   4  3.28872000   980.43501900
# 4   6.58304000  1502943899999  1970.70098150   8  0.51388000   153.87400150
#
#                11
# 0  46530.96364628
# 1  46577.43872919
# ...

# %%
df.columns = ["Open time", "Open", "High", "Low", "Close", "Volume", "Close time", "Quote asset volume", "Number of trades", "Taker buy base asset volume", "Taker buy quote asset volume", "Ignore"]

# %%
df.tail()
# Out:
#             Open time           Open           High            Low  \
# 418138  1628882700000  3224.40000000  3224.40000000  3212.00000000
# 418139  1628883000000  3214.27000000  3221.59000000  3213.50000000
# 418140  1628883300000  3218.56000000  3219.25000000  3213.00000000
# 418141  1628883600000  3219.24000000  3220.04000000  3216.15000000
# 418142  1628883900000  3216.56000000  3222.37000000  3216.21000000
#
#                 Close         Volume     Close time Quote asset volume  \
# 418138  3214.27000000  1147.87318000  1628882999999   3692476.15360080
# 418139  3218.57000000  1051.07379000  1628883299999   3382250.45879530
# 418140  3219.24000000   518.49877000  1628883599999   1667337.79978590
# 418141  3216.56000000   750.72523000  1628883899999   2415968.76523840
# 418142  3222.01000000   361.08422000  1628884199999   1162633.85519720
#
#         Number of trades Taker buy base asset volume  \
# 418138              2763                464.02754000
# ...

# %%
df.to_csv('./data/ETH_30_July_2015_to_14_08_2021_5min.csv')
